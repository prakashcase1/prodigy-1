# %%
import numpy as np
import pandas as pd
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# File paths
file1 = 'C:/Users/SAI/Downloads/Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_344555.csv'
file2 = 'C:/Users/SAI/Downloads/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_344555.csv'
file3 = 'C:/Users/SAI/Downloads/API_SP.POP.TOTL_DS2_en_csv_v2_344555.csv'


expected_number_of_columns = 3  # Update this with the actual number of columns in your files

# Define rows to skip if encountering parsing errors
skip_rows = []

# Define empty DataFrames
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()

# Read the CSV files, skipping problematic rows
try:
    df1 = pd.read_csv(file1)
except pd.errors.ParserError as e:
    print(f"Error parsing file {file1}: {e}")
    # Identify problematic rows
    skip_rows += [index for index, line in enumerate(open(file1, 'r')) if len(line.split(',')) != expected_number_of_columns]

try:
    df2 = pd.read_csv(file2)
except pd.errors.ParserError as e:
    print(f"Error parsing file {file2}: {e}")
    # Identify problematic rows
    skip_rows += [index for index, line in enumerate(open(file2, 'r')) if len(line.split(',')) != expected_number_of_columns]

try:
    df3 = pd.read_csv(file3)
except pd.errors.ParserError as e:
    print(f"Error parsing file {file3}: {e}")
    # Identify problematic rows
    skip_rows += [index for index, line in enumerate(open(file3, 'r')) if len(line.split(',')) != expected_number_of_columns]

# Combine the DataFrames into a single DataFrame
combined_df = pd.concat([df1, df2, df3], ignore_index=True)

# Display the combined DataFrame
print(combined_df.head())

combined_df = pd.concat([df1, df2, df3], axis=1)
# Out:
# Error parsing file C:/Users/SAI/Downloads/API_SP.POP.TOTL_DS2_en_csv_v2_344555.csv: Error tokenizing data. C error: Expected 3 fields in line 5, saw 69
#
#   INDICATOR_CODE     INDICATOR_NAME  \
# 0    SP.POP.TOTL  Population, total
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
#
#                                          SOURCE_NOTE  \
# 0  Total population is based on the de facto defi...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4 Country Code  \
# 0  (1) United Nations Population Division. World ...         NaN          NaN
# 1                                                NaN         NaN          ABW
# ...

# %%
# Count the occurrences of each region in the 'Region' column
gender_counts = data['Region'].value_counts()

# Plot a bar chart using Seaborn's countplot
sns.barplot(x=gender_counts.index, y=gender_counts.values, palette='muted')

# Customize the plot
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Distribution of Region')
plt.xticks(rotation=90)

# Add count numbers above each bar
for x, y in enumerate(gender_counts.values):
    plt.text(x, y, str(y), ha='center', va='bottom')
    
# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add a grid to the plot
plt.grid(axis='y', linestyle='--', alpha=0.5)


# Display the bar chart
plt.tight_layout()
plt.show()
